# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from scipy import stats
import math

# %%
def unique(list1):
 
    # intilize a null list
    unique_list = []
     
    # traverse for all elements
    for x in list1:
        # check if exists in unique_list or not
        if x not in unique_list:
            unique_list.append(x)
    return unique_list

def reduce_to_first_significant_digit(quantity, uncertainty):
    first_significant_digit = math.floor(math.log10(abs(uncertainty)))
    quantity = round(quantity, -first_significant_digit)
    uncertainty = round(uncertainty, -first_significant_digit)
    return quantity, uncertainty

def plot_correlation_with_SEM(x_lab, y_lab, data, x_err, y_err, title=None, color=None, ax=None):
    # Extract only pKa values.
    x_error = data.loc[:, x_err]
    y_error = data.loc[:, y_err]
    x_values = data.loc[:, x_lab]
    y_values = data.loc[:, y_lab]
    data = data[[x_lab, y_lab]]

    # Find extreme values to make axes equal.
    #min_limit = np.ceil(min(data.min()) -2)
    #max_limit = np.floor(max(data.max()) +2)
    min_limit = 2
    max_limit = 12
    axes_limits = np.array([min_limit, max_limit])
    print("axes limits: ", axes_limits)
    
    # Color
    current_palette = sns.color_palette()
    sns_blue = current_palette[0]
    
    # Plot
    plt.figure(figsize=(6,6))
    grid = sns.regplot(x=x_values, y=y_values, data=data, color=color, ci=None)#scatter_kws={'s':10}
    plt.errorbar(x=x_values, y=y_values, xerr=x_error, yerr=y_error,fmt = "o", ecolor=sns_blue, capthick='2', label='SEM', alpha=0.75, markersize='5')
    plt.title(title)
    plt.axis("equal")
    
    # Add diagonal line.
    grid.plot(axes_limits, axes_limits, ls='--', c='black', alpha=0.8, lw=0.7)

    # Add shaded area for 0.5-1 pKa error.
    palette = sns.color_palette('BuGn_r')
    grid.fill_between(axes_limits, axes_limits - 0.5, axes_limits + 0.5, alpha=0.2, color=palette[2])
    grid.fill_between(axes_limits, axes_limits - 1, axes_limits + 1, alpha=0.2, color=palette[3])
    
    plt.xlim(axes_limits)
    plt.ylim(axes_limits)
    
def r2(data):
    x, y = data.T
    slope, intercept, r_value, p_value, stderr = stats.linregress(x, y)
    return r_value**2

def slope(data):
    x, y = data.T
    slope, intercept, r_value, p_value, stderr = stats.linregress(x, y)
    return slope

def me(data):
    x, y = data.T
    error = np.array(x) - np.array(y)
    return error.mean()

def mae(data):
    x, y = data.T
    error = np.abs(np.array(x) - np.array(y))
    return error.mean()


def rmse(data):
    x, y = data.T
    error = np.array(x) - np.array(y)
    rmse = np.sqrt((error**2).mean())
    return rmse

# %% [markdown]
# ## Calculate pKa mean and SEM for replicate measurements

# %%
data_path = "water_vs_cosolvent_pKa_values_including_pyridoxineHCl.csv"

df_replicates = pd.read_csv(data_path)

# Convert ">12" cosolvent value of SM06 to NaN
df_replicates.loc[11, "pKa2"] = np.NaN
df_replicates.loc[12, "pKa2"] = np.NaN
df_replicates.loc[13, "pKa2"] = np.NaN
# Convert also SM06 pKa2 from non-cosolvent experiments to NaN because cosolvent data is misisng
df_replicates.loc[8, "pKa2"] = np.NaN
df_replicates.loc[9, "pKa2"] = np.NaN
df_replicates.loc[10, "pKa2"] = np.NaN

df_replicates
# Out:
#        Molecule ID  pKa1   pKa2  pKa3  \
# 0             SM01  9.54    NaN   NaN
# 1             SM01  9.53    NaN   NaN
# 2             SM01  9.53    NaN   NaN
# 3             SM01  9.71    NaN   NaN
# 4             SM04  6.03    NaN   NaN
# 5             SM04  6.02    NaN   NaN
# 6             SM04  6.02    NaN   NaN
# 7             SM04  5.97    NaN   NaN
# 8             SM06  2.96    NaN   NaN
# 9             SM06  3.11    NaN   NaN
# 10            SM06  3.02    NaN   NaN
# 11            SM06  3.46    NaN   NaN
# 12            SM06  3.40    NaN   NaN
# 13            SM06  3.45    NaN   NaN
# 14            SM07  6.07    NaN   NaN
# 15            SM07  6.07    NaN   NaN
# 16            SM07  6.09    NaN   NaN
# 17            SM07  5.96    NaN   NaN
# 18            SM08  4.23    NaN   NaN
# 19            SM08  4.20    NaN   NaN
# 20            SM08  4.22    NaN   NaN
# 21            SM08  4.47    NaN   NaN
# 22            SM11  3.89    NaN   NaN
# 23            SM11  3.89    NaN   NaN
# 24            SM11  3.89    NaN   NaN
# 25            SM11  3.74    NaN   NaN
# 26            SM12  5.28    NaN   NaN
# 27            SM12  5.28    NaN   NaN
# 28            SM12  5.27    NaN   NaN
# 29            SM12  5.16    NaN   NaN
# 30            SM13  5.79    NaN   NaN
# 31            SM13  5.76    NaN   NaN
# 32            SM13  5.76    NaN   NaN
# 33            SM13  5.68    NaN   NaN
# 34            SM14  2.59   5.31   NaN
# 35            SM14  2.57   5.29   NaN
# 36            SM14  2.57   5.29   NaN
# 37            SM14  2.56   5.29   NaN
# 38            SM15  4.71   8.96   NaN
# 39            SM15  4.70   8.94   NaN
# 40            SM15  4.69   8.92   NaN
# 41            SM15  4.67   9.01   NaN
# 42            SM16  5.37  10.64   NaN
# 43            SM16  5.37  10.65   NaN
# 44            SM16  5.38  10.65   NaN
# 45            SM16  5.35  11.01   NaN
# 46            SM17  3.15    NaN   NaN
# 47            SM17  3.16    NaN   NaN
# 48            SM17  3.17    NaN   NaN
# 49            SM17  3.20    NaN   NaN
# 50  Pyridoxine HCl  4.81   8.85   NaN
# 51  Pyridoxine HCl  4.83   8.87   NaN
# 52  Pyridoxine HCl  4.84   8.86   NaN
# 53  Pyridoxine HCl  4.85   8.79   NaN
# 54  Pyridoxine HCl  4.85   8.79   NaN
# 55  Pyridoxine HCl  4.86   8.77   NaN
#
#                                          Assay Type Experiment ID  \
# 0                                     UV-metric pKa     17I-15024
# 1                                     UV-metric pKa     17I-15025
# 2                                     UV-metric pKa     17I-16001
# 3   UV-metric psKa, Yasuda-Shedlovsky Extrapolation     17J-06011
# 4                                     UV-metric pKa     17I-18018
# 5                                     UV-metric pKa     17I-18019
# 6                                     UV-metric pKa     17I-18020
# 7   UV-metric psKa, Yasuda-Shedlovsky Extrapolation     17K-09020
# 8                                     UV-metric pKa     17I-18021
# 9                                     UV-metric pKa     17I-18022
# 10                                    UV-metric pKa     17I-18023
# 11  UV-metric psKa, Yasuda-Shedlovsky Extrapolation     17K-09021
# 12  UV-metric psKa, Yasuda-Shedlovsky Extrapolation     17K-10008
# 13  UV-metric psKa, Yasuda-Shedlovsky Extrapolation     17K-16011
# 14                                    UV-metric pKa     17I-16002
# 15                                    UV-metric pKa     17I-16004
# 16                                    UV-metric pKa     17I-20001
# 17  UV-metric psKa, Yasuda-Shedlovsky Extrapolation     17J-12006
# 18                                    UV-metric pKa     17I-19001
# 19                                    UV-metric pKa     17I-19002
# 20                                    UV-metric pKa     17I-19003
# 21  UV-metric psKa, Yasuda-Shedlovsky Extrapolation     17J-12007
# 22                                    UV-metric pKa     17I-16005
# 23                                    UV-metric pKa     17I-16006
# 24                                    UV-metric pKa     17I-16007
# 25  UV-metric psKa, Yasuda-Shedlovsky Extrapolation     17J-04003
# 26                                    UV-metric pKa     17I-21002
# 27                                    UV-metric pKa     17I-21003
# 28                                    UV-metric pKa     17I-21004
# 29  UV-metric psKa, Yasuda-Shedlovsky Extrapolation     17J-11014
# 30                                    UV-metric pKa     17I-16011
# 31                                    UV-metric pKa     17I-16012
# 32                                    UV-metric pKa     17I-16013
# 33  UV-metric psKa, Yasuda-Shedlovsky Extrapolation     17J-04005
# 34                                    UV-metric pKa     17I-29002
# 35                                    UV-metric pKa     17I-29003
# 36                                    UV-metric pKa     17I-29004
# 37  UV-metric psKa, Yasuda-Shedlovsky Extrapolation     17J-12008
# 38                                    UV-metric pKa     17K-10009
# 39                                    UV-metric pKa     17K-10010
# 40                                    UV-metric pKa     17K-10011
# 41  UV-metric psKa, Yasuda-Shedlovsky Extrapolation     17J-12009
# 42                                    UV-metric pKa     17J-03025
# 43                                    UV-metric pKa     17J-03026
# 44                                    UV-metric pKa     17J-03027
# 45  UV-metric psKa, Yasuda-Shedlovsky Extrapolation     17J-12010
# 46                                    UV-metric pKa     17J-02024
# 47                                    UV-metric pKa     17J-02025
# 48                                    UV-metric pKa     17J-02026
# 49  UV-metric psKa, Yasuda-Shedlovsky Extrapolation     17J-12011
# 50                                    UV-metric pKa     18E-22003
# 51                                    UV-metric pKa     18E-22004
# 52                                    UV-metric pKa     18E-22010
# 53  UV-metric psKa, Yasuda-Shedlovsky Extrapolation     18E-22011
# 54  UV-metric psKa, Yasuda-Shedlovsky Extrapolation     18E-22012
# 55  UV-metric psKa, Yasuda-Shedlovsky Extrapolation     18E-22013
#
#    Experimental Molecule ID  \
# 0                       M01
# 1                       M01
# 2                       M01
# 3                       M01
# 4                       M04
# 5                       M04
# 6                       M04
# 7                       M04
# 8                       M06
# 9                       M06
# 10                      M06
# 11                      M06
# 12                      M06
# 13                      M06
# 14                      M07
# 15                      M07
# 16                      M07
# 17                      M07
# 18                      M08
# 19                      M08
# 20                      M08
# 21                      M08
# 22                      M11
# 23                      M11
# 24                      M11
# 25                      M11
# 26                      M12
# 27                      M12
# 28                      M12
# 29                      M12
# 30                      M13
# 31                      M13
# 32                      M13
# 33                      M13
# 34                      M15
# 35                      M15
# 36                      M15
# 37                      M15
# 38                      M16
# 39                      M16
# 40                      M16
# 41                      M16
# 42                      M18
# 43                      M18
# 44                      M18
# 45                      M18
# 46                      M19
# 47                      M19
# 48                      M19
# 49                      M19
# 50           Pyridoxine HCl
# 51           Pyridoxine HCl
# 52           Pyridoxine HCl
# 53           Pyridoxine HCl
# 54           Pyridoxine HCl
# 55           Pyridoxine HCl
#
#                                     Experiment Report  \
# 0         SM01_17I-15024_M01_UV-metric pKa_report.pdf
# 1         SM01_17I-15025_M01_UV-metric pKa_report.pdf
# 2         SM01_17I-16001_M01_UV-metric pKa_report.pdf
# 3        SM01_17J-06011_M01_UV-metric psKa_report.pdf
# 4         SM04_17I-18018_M04_UV-metric pKa_report.pdf
# 5         SM04_17I-18019_M04_UV-metric pKa_report.pdf
# 6         SM04_17I-18020_M04_UV-metric pKa_report.pdf
# 7        SM04_17K-09020_M04_UV-metric psKa_report.pdf
# 8         SM06_17I-18021_M06_UV-metric pKa_report.pdf
# 9         SM06_17I-18022_M06_UV-metric pKa_report.pdf
# 10        SM06_17I-18023_M06_UV-metric pKa_report.pdf
# 11       SM06_17K-09021_M06_UV-metric psKa_report.pdf
# 12       SM06_17K-10008_M06_UV-metric psKa_report.pdf
# 13       SM06_17K-16011_M06_UV-metric psKa_report.pdf
# 14        SM07_17I-16002_M07_UV-metric pKa_report.pdf
# 15        SM07_17I-16004_M07_UV-metric pKa_report.pdf
# 16        SM07_17I-20001_M07_UV-metric pKa_report.pdf
# 17       SM07_17J-12006_M07_UV-metric psKa_report.pdf
# 18        SM08_17I-19001_M08_UV-metric pKa_report.pdf
# 19        SM08_17I-19002_M08_UV-metric pKa_report.pdf
# 20        SM08_17I-19003_M08_UV-metric pKa_report.pdf
# 21       SM08_17J-12007_M08_UV-metric psKa_report.pdf
# 22        SM11_17I-16005_M11_UV-metric pKa_report.pdf
# 23        SM11_17I-16006_M11_UV-metric pKa_report.pdf
# 24        SM11_17I-16007_M11_UV-metric pKa_report.pdf
# 25       SM11_17J-04003_M11_UV-metric psKa_report.pdf
# 26        SM12_17I-21002_M12_UV-metric pKa_report.pdf
# 27        SM12_17I-21003_M12_UV-metric pKa_report.pdf
# 28        SM12_17I-21004_M12_UV-metric pKa_report.pdf
# 29       SM12_17J-11014_M12_UV-metric psKa_report.pdf
# 30        SM13_17I-16011_M13_UV-metric pKa_report.pdf
# 31        SM13_17I-16012_M13_UV-metric pKa_report.pdf
# 32        SM13_17I-16013_M13_UV-metric pKa_report.pdf
# 33       SM13_17J-04005_M13_UV-metric psKa_report.pdf
# 34        SM14_17I-29002_M15_UV-metric pKa_report.pdf
# 35        SM14_17I-29003_M15_UV-metric pKa_report.pdf
# 36        SM14_17I-29004_M15_UV-metric pKa_report.pdf
# 37       SM14_17J-12008_M15_UV-metric psKa_report.pdf
# 38        SM15_17K-10009_M16_UV-metric pKa_report.pdf
# 39        SM15_17K-10010_M16_UV-metric pKa_report.pdf
# 40        SM15_17K-10011_M16_UV-metric pKa_report.pdf
# 41       SM15_17J-12009_M16_UV-metric psKa_report.pdf
# 42        SM16_17J-03025_M18_UV-metric pKa_report.pdf
# 43        SM16_17J-03026_M18_UV-metric pKa_report.pdf
# 44        SM16_17J-03027_M18_UV-metric pKa_report.pdf
# 45       SM16_17J-12010_M18_UV-metric psKa_report.pdf
# 46        SM17_17J-02024_M19_UV-metric pKa_report.pdf
# 47        SM17_17J-02025_M19_UV-metric pKa_report.pdf
# 48        SM17_17J-02026_M19_UV-metric pKa_report.pdf
# 49       SM17_17J-12011_M19_UV-metric psKa_report.pdf
# 50  18E-22003_Pyridoxine HCl_UV-metric pKa_0417936...
# 51  18E-22004_Pyridoxine HCl_UV-metric pKa_0417936...
# 52  18E-22010_Pyridoxine HCl_UV-metric pKa_0417936...
# 53  18E-22011_Pyridoxine HCl_UV-metric psKa_041793...
# 54  18E-22012_Pyridoxine HCl_UV-metric psKa_041793...
# 55  18E-22013_Pyridoxine HCl_UV-metric psKa_041793...
#
#                       canonical isomeric SMILES  \
# 0                 c1cc2c(cc1O)c3c(o2)C(=O)NCCC3
# 1                 c1cc2c(cc1O)c3c(o2)C(=O)NCCC3
# 2                 c1cc2c(cc1O)c3c(o2)C(=O)NCCC3
# 3                 c1cc2c(cc1O)c3c(o2)C(=O)NCCC3
# 4              c1ccc2c(c1)c(ncn2)NCc3ccc(cc3)Cl
# 5              c1ccc2c(c1)c(ncn2)NCc3ccc(cc3)Cl
# 6              c1ccc2c(c1)c(ncn2)NCc3ccc(cc3)Cl
# 7              c1ccc2c(c1)c(ncn2)NCc3ccc(cc3)Cl
# 8            c1cc2cccnc2c(c1)NC(=O)c3cc(cnc3)Br
# 9            c1cc2cccnc2c(c1)NC(=O)c3cc(cnc3)Br
# 10           c1cc2cccnc2c(c1)NC(=O)c3cc(cnc3)Br
# 11           c1cc2cccnc2c(c1)NC(=O)c3cc(cnc3)Br
# 12           c1cc2cccnc2c(c1)NC(=O)c3cc(cnc3)Br
# 13           c1cc2cccnc2c(c1)NC(=O)c3cc(cnc3)Br
# 14                   c1ccc(cc1)CNc2c3ccccc3ncn2
# 15                   c1ccc(cc1)CNc2c3ccccc3ncn2
# 16                   c1ccc(cc1)CNc2c3ccccc3ncn2
# 17                   c1ccc(cc1)CNc2c3ccccc3ncn2
# 18  Cc1ccc2c(c1)c(c(c(=O)[nH]2)CC(=O)O)c3ccccc3
# 19  Cc1ccc2c(c1)c(c(c(=O)[nH]2)CC(=O)O)c3ccccc3
# 20  Cc1ccc2c(c1)c(c(c(=O)[nH]2)CC(=O)O)c3ccccc3
# 21  Cc1ccc2c(c1)c(c(c(=O)[nH]2)CC(=O)O)c3ccccc3
# 22                 c1ccc(cc1)n2c3c(cn2)c(ncn3)N
# 23                 c1ccc(cc1)n2c3c(cn2)c(ncn3)N
# 24                 c1ccc(cc1)n2c3c(cn2)c(ncn3)N
# 25                 c1ccc(cc1)n2c3c(cn2)c(ncn3)N
# 26           c1ccc2c(c1)c(ncn2)Nc3cccc(c3)Cl.Cl
# 27           c1ccc2c(c1)c(ncn2)Nc3cccc(c3)Cl.Cl
# 28           c1ccc2c(c1)c(ncn2)Nc3cccc(c3)Cl.Cl
# 29           c1ccc2c(c1)c(ncn2)Nc3cccc(c3)Cl.Cl
# 30           Cc1cccc(c1)Nc2c3cc(c(cc3ncn2)OC)OC
# 31           Cc1cccc(c1)Nc2c3cc(c(cc3ncn2)OC)OC
# 32           Cc1cccc(c1)Nc2c3cc(c(cc3ncn2)OC)OC
# 33           Cc1cccc(c1)Nc2c3cc(c(cc3ncn2)OC)OC
# 34                   c1ccc(cc1)n2cnc3c2ccc(c3)N
# 35                   c1ccc(cc1)n2cnc3c2ccc(c3)N
# 36                   c1ccc(cc1)n2cnc3c2ccc(c3)N
# 37                   c1ccc(cc1)n2cnc3c2ccc(c3)N
# 38                   c1ccc2c(c1)ncn2c3ccc(cc3)O
# 39                   c1ccc2c(c1)ncn2c3ccc(cc3)O
# 40                   c1ccc2c(c1)ncn2c3ccc(cc3)O
# 41                   c1ccc2c(c1)ncn2c3ccc(cc3)O
# 42             c1cc(c(c(c1)Cl)C(=O)Nc2ccncc2)Cl
# 43             c1cc(c(c(c1)Cl)C(=O)Nc2ccncc2)Cl
# 44             c1cc(c(c(c1)Cl)C(=O)Nc2ccncc2)Cl
# 45             c1cc(c(c(c1)Cl)C(=O)Nc2ccncc2)Cl
# 46                c1ccc(cc1)CSc2nnc(o2)c3ccncc3
# 47                c1ccc(cc1)CSc2nnc(o2)c3ccncc3
# 48                c1ccc(cc1)CSc2nnc(o2)c3ccncc3
# 49                c1ccc(cc1)CSc2nnc(o2)c3ccncc3
# 50                     CC1=NC=C(C(=C1O)CO)CO.Cl
# 51                     CC1=NC=C(C(=C1O)CO)CO.Cl
# 52                     CC1=NC=C(C(=C1O)CO)CO.Cl
# 53                     CC1=NC=C(C(=C1O)CO)CO.Cl
# 54                     CC1=NC=C(C(=C1O)CO)CO.Cl
# 55                     CC1=NC=C(C(=C1O)CO)CO.Cl
#
#                                          Notes
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3   not used for the analysis of predicted pKa
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7   not used for the analysis of predicted pKa
# 8                                          NaN
# 9                                          NaN
# 10                                         NaN
# 11  not used for the analysis of predicted pKa
# 12  not used for the analysis of predicted pKa
# 13  not used for the analysis of predicted pKa
# 14                                         NaN
# 15                                         NaN
# 16                                         NaN
# 17  not used for the analysis of predicted pKa
# 18                                         NaN
# 19                                         NaN
# 20                                         NaN
# 21  not used for the analysis of predicted pKa
# 22                                         NaN
# 23                                         NaN
# 24                                         NaN
# 25  not used for the analysis of predicted pKa
# 26                                         NaN
# 27                                         NaN
# 28                                         NaN
# 29  not used for the analysis of predicted pKa
# 30                                         NaN
# 31                                         NaN
# 32                                         NaN
# 33  not used for the analysis of predicted pKa
# 34                                         NaN
# 35                                         NaN
# 36                                         NaN
# 37  not used for the analysis of predicted pKa
# 38                                         NaN
# 39                                         NaN
# 40                                         NaN
# 41  not used for the analysis of predicted pKa
# 42                                         NaN
# 43                                         NaN
# 44                                         NaN
# 45  not used for the analysis of predicted pKa
# 46                                         NaN
# 47                                         NaN
# 48                                         NaN
# 49  not used for the analysis of predicted pKa
# 50           not included in the pKa challenge
# 51           not included in the pKa challenge
# 52           not included in the pKa challenge
# 53           not included in the pKa challenge
# 54           not included in the pKa challenge
# 55           not included in the pKa challenge

# %%
mol_IDs = unique(list(df_replicates["Molecule ID"]))
mol_IDs
# Out:
# ['SM01',
#  'SM04',
#  'SM06',
#  'SM07',
#  'SM08',
#  'SM11',
#  'SM12',
#  'SM13',
#  'SM14',
#  'SM15',
#  'SM16',
#  'SM17',
#  'Pyridoxine HCl']

# %%
df_stat = pd.DataFrame(columns = ["Molecule ID", "pKa ID", "pKa mean", "pKa SEM", "Assay Type"])
df_stat
# Out:
# Empty DataFrame
# Columns: [Molecule ID, pKa ID, pKa mean, pKa SEM, Assay Type]
# Index: []

# %%
for mol_ID in mol_IDs:
    #print("Mol ID:", mol_ID)
    df_mol = df_replicates.loc[df_replicates["Molecule ID"] == mol_ID ]
    # check how many water and cosolvent pKa measurements were done
    df_mol_water = df_mol.loc[df_replicates["Assay Type"] == "UV-metric pKa" ]
    df_mol_cosolvent = df_mol.loc[df_replicates["Assay Type"] == "UV-metric psKa, Yasuda-Shedlovsky Extrapolation"]
    
    # calculate mean and SEM if there are replicate experiments
    if df_mol_water.shape[0] > 0:
        # iterate over pKa1, pKa2 and pKa3
        for i in range(3):
            pKa_ID = "pKa{}".format(i+1)
            assay_type = "UV-metric pKa"
            pKa_array = pd.to_numeric(df_mol_water[pKa_ID], errors='coerce')
            #print(pKa_array)
        
            # Calculate mean of 3 replicates format(a, '.2f')
            pKa_mean =  float(format(np.mean(pKa_array), '.2f'))
            #print("mean:", pKa_mean)
            # Calculate standard error of the mean (SEM)
            # ddof=0 provides a maximum likelihood estimate of the variance for normally distributed variables
            pKa_SEM = stats.sem(pKa_array, ddof = 0)
            #print("SEM:", pKa_SEM)
            
            s = pd.Series([mol_ID, pKa_ID, pKa_mean,pKa_SEM, assay_type], index = df_stat.columns)
            df_stat = df_stat.append(s, ignore_index=True)
            
    if df_mol_cosolvent.shape[0] > 0:
        # iterate over pKa1, pKa2 and pKa3
        for i in range(3):
            pKa_ID = "pKa{}".format(i+1)
            assay_type = "UV-metric psKa, Yasuda-Shedlovsky Extrapolation"
            pKa_array = pd.to_numeric(df_mol_cosolvent[pKa_ID], errors='coerce')
            #print(pKa_array)
        
            # Calculate mean of 3 replicates format(a, '.2f')
            pKa_mean =  float(format(np.mean(pKa_array), '.2f'))
            #print("mean:", pKa_mean)
            
            if df_mol_cosolvent.shape[0] > 1:
                # Calculate standard error of the mean (SEM)
                # ddof=0 provides a maximum likelihood estimate of the variance for normally distributed variables
                pKa_SEM = stats.sem(pKa_array, ddof = 0)
           
            else:
                pKa_SEM = np.NaN
            #print("SEM:", pKa_SEM)
            
            s = pd.Series([mol_ID, pKa_ID, pKa_mean,pKa_SEM, assay_type], index = df_stat.columns)
            df_stat = df_stat.append(s, ignore_index=True)

# %%
# Remove lines without a measuremnt for pKa mean  
df_stat = df_stat.loc[~np.isnan(df_stat["pKa mean"])].reset_index(drop=True)

# %%
# Reduce SEM values to 1st significat digit
# Since pKa experimental data was reported in 2 decimal points, 
# SEM will be reported as 0.01 if calculated SEM value from 3 replicates is lower than 0.01.
minimum_SEM = float(0.01)

for i, row in enumerate(df_stat.iterrows()):
    pKa_SEM = row[1]["pKa SEM"]
    pKa_mean = row[1]["pKa mean"]
    if np.isnan(pKa_SEM):
        continue
    else:
        pKa_SEM = max(minimum_SEM, pKa_SEM)
        pKa_SEM = reduce_to_first_significant_digit(pKa_mean,pKa_SEM)[1]
        pKa_SEM = str(format(pKa_SEM, '.2f'))
    df_stat.loc[i, "pKa SEM"] = pKa_SEM

# %%
# Change pKa IDs to unique pKa IDs
for i, row in enumerate(df_stat.iterrows()):
    mol_ID = row[1]["Molecule ID"]
    pKa_ID = row[1]["pKa ID"]
    pKa_ID = mol_ID + "_" + pKa_ID
    df_stat.loc[i, "pKa ID"] =  pKa_ID
df_stat
# Out:
#        Molecule ID               pKa ID  pKa mean pKa SEM  \
# 0             SM01            SM01_pKa1      9.53    0.01
# 1             SM01            SM01_pKa1      9.71     NaN
# 2             SM04            SM04_pKa1      6.02    0.01
# 3             SM04            SM04_pKa1      5.97     NaN
# 4             SM06            SM06_pKa1      3.03    0.04
# 5             SM06            SM06_pKa1      3.44    0.02
# 6             SM07            SM07_pKa1      6.08    0.01
# 7             SM07            SM07_pKa1      5.96     NaN
# 8             SM08            SM08_pKa1      4.22    0.01
# 9             SM08            SM08_pKa1      4.47     NaN
# 10            SM11            SM11_pKa1      3.89    0.01
# 11            SM11            SM11_pKa1      3.74     NaN
# 12            SM12            SM12_pKa1      5.28    0.01
# 13            SM12            SM12_pKa1      5.16     NaN
# 14            SM13            SM13_pKa1      5.77    0.01
# 15            SM13            SM13_pKa1      5.68     NaN
# 16            SM14            SM14_pKa1      2.58    0.01
# 17            SM14            SM14_pKa2      5.30    0.01
# 18            SM14            SM14_pKa1      2.56     NaN
# 19            SM14            SM14_pKa2      5.29     NaN
# 20            SM15            SM15_pKa1      4.70    0.01
# 21            SM15            SM15_pKa2      8.94    0.01
# 22            SM15            SM15_pKa1      4.67     NaN
# 23            SM15            SM15_pKa2      9.01     NaN
# 24            SM16            SM16_pKa1      5.37    0.01
# 25            SM16            SM16_pKa2     10.65    0.01
# 26            SM16            SM16_pKa1      5.35     NaN
# 27            SM16            SM16_pKa2     11.01     NaN
# 28            SM17            SM17_pKa1      3.16    0.01
# 29            SM17            SM17_pKa1      3.20     NaN
# 30  Pyridoxine HCl  Pyridoxine HCl_pKa1      4.83    0.01
# 31  Pyridoxine HCl  Pyridoxine HCl_pKa2      8.86    0.01
# 32  Pyridoxine HCl  Pyridoxine HCl_pKa1      4.85    0.01
# 33  Pyridoxine HCl  Pyridoxine HCl_pKa2      8.78    0.01
#
#                                          Assay Type
# 0                                     UV-metric pKa
# 1   UV-metric psKa, Yasuda-Shedlovsky Extrapolation
# 2                                     UV-metric pKa
# 3   UV-metric psKa, Yasuda-Shedlovsky Extrapolation
# 4                                     UV-metric pKa
# 5   UV-metric psKa, Yasuda-Shedlovsky Extrapolation
# 6                                     UV-metric pKa
# 7   UV-metric psKa, Yasuda-Shedlovsky Extrapolation
# 8                                     UV-metric pKa
# 9   UV-metric psKa, Yasuda-Shedlovsky Extrapolation
# 10                                    UV-metric pKa
# 11  UV-metric psKa, Yasuda-Shedlovsky Extrapolation
# 12                                    UV-metric pKa
# 13  UV-metric psKa, Yasuda-Shedlovsky Extrapolation
# 14                                    UV-metric pKa
# 15  UV-metric psKa, Yasuda-Shedlovsky Extrapolation
# 16                                    UV-metric pKa
# 17                                    UV-metric pKa
# 18  UV-metric psKa, Yasuda-Shedlovsky Extrapolation
# 19  UV-metric psKa, Yasuda-Shedlovsky Extrapolation
# 20                                    UV-metric pKa
# 21                                    UV-metric pKa
# 22  UV-metric psKa, Yasuda-Shedlovsky Extrapolation
# 23  UV-metric psKa, Yasuda-Shedlovsky Extrapolation
# 24                                    UV-metric pKa
# 25                                    UV-metric pKa
# 26  UV-metric psKa, Yasuda-Shedlovsky Extrapolation
# 27  UV-metric psKa, Yasuda-Shedlovsky Extrapolation
# 28                                    UV-metric pKa
# 29  UV-metric psKa, Yasuda-Shedlovsky Extrapolation
# 30                                    UV-metric pKa
# 31                                    UV-metric pKa
# 32  UV-metric psKa, Yasuda-Shedlovsky Extrapolation
# 33  UV-metric psKa, Yasuda-Shedlovsky Extrapolation

# %%
# Organize the dataframe so that water and cosolvent pKas are side by side

df_stat_water = df_stat.loc[df_stat["Assay Type"] == "UV-metric pKa"].reset_index(drop=True)
df_stat_water = df_stat_water.drop("Assay Type", 1)
df_stat_water.columns = ["Molecule ID", "pKa ID", "pKa mean water", "pKa SEM water"]

df_stat_cosolvent = df_stat.loc[df_stat["Assay Type"] == "UV-metric psKa, Yasuda-Shedlovsky Extrapolation"].reset_index(drop=True)
df_stat_cosolvent = df_stat_cosolvent.drop("Assay Type", 1)
df_stat_cosolvent.columns = ["Molecule ID2", "pKa ID2", "pKa mean cosolvent", "pKa SEM cosolvent"]

# %%
df_stat_conc = pd.concat([df_stat_water, df_stat_cosolvent], axis=1)
df_stat_conc  = df_stat_conc .drop("Molecule ID2", 1)
df_stat_conc  = df_stat_conc .drop("pKa ID2", 1)
df_stat_conc
# Out:
#        Molecule ID               pKa ID  pKa mean water pKa SEM water  \
# 0             SM01            SM01_pKa1            9.53          0.01
# 1             SM04            SM04_pKa1            6.02          0.01
# 2             SM06            SM06_pKa1            3.03          0.04
# 3             SM07            SM07_pKa1            6.08          0.01
# 4             SM08            SM08_pKa1            4.22          0.01
# 5             SM11            SM11_pKa1            3.89          0.01
# 6             SM12            SM12_pKa1            5.28          0.01
# 7             SM13            SM13_pKa1            5.77          0.01
# 8             SM14            SM14_pKa1            2.58          0.01
# 9             SM14            SM14_pKa2            5.30          0.01
# 10            SM15            SM15_pKa1            4.70          0.01
# 11            SM15            SM15_pKa2            8.94          0.01
# 12            SM16            SM16_pKa1            5.37          0.01
# 13            SM16            SM16_pKa2           10.65          0.01
# 14            SM17            SM17_pKa1            3.16          0.01
# 15  Pyridoxine HCl  Pyridoxine HCl_pKa1            4.83          0.01
# 16  Pyridoxine HCl  Pyridoxine HCl_pKa2            8.86          0.01
#
#     pKa mean cosolvent pKa SEM cosolvent
# 0                 9.71               NaN
# 1                 5.97               NaN
# 2                 3.44              0.02
# 3                 5.96               NaN
# 4                 4.47               NaN
# 5                 3.74               NaN
# 6                 5.16               NaN
# 7                 5.68               NaN
# 8                 2.56               NaN
# 9                 5.29               NaN
# 10                4.67               NaN
# 11                9.01               NaN
# 12                5.35               NaN
# 13               11.01               NaN
# 14                3.20               NaN
# 15                4.85              0.01
# 16                8.78              0.01

# %%
# Correct dtype of SEM columns
cols = ['pKa SEM water', 'pKa SEM cosolvent']
df_stat_conc[cols] = df_stat_conc[cols].apply(pd.to_numeric, errors='coerce', axis=1)
df_stat_conc.dtypes
# Out:
# Molecule ID            object
# pKa ID                 object
# pKa mean water        float64
# pKa SEM water         float64
# pKa mean cosolvent    float64
# pKa SEM cosolvent     float64
# dtype: object

# %%
data = df_stat_conc
data.columns = ["Molecule ID", "pKa ID", "pKa (UV-metric pKa)", "pKa SEM water", "pKa (UV-metric pKa with cosolvent)", "pKa SEM cosolvent"]

plt.close()
plot_correlation_with_SEM(x_lab="pKa (UV-metric pKa)", y_lab="pKa (UV-metric pKa with cosolvent)",data = data, x_err="pKa SEM water", y_err="pKa SEM cosolvent")
plt.show()
# Out:
# axes limits:  [ 2 12]

# %% [markdown]
# ## Calculate statistical difference between UV-metric pKa and UV-metric pKa with cosolvent

# %%
df_stat_conc
# Out:
#        Molecule ID               pKa ID  pKa (UV-metric pKa)  pKa SEM water  \
# 0             SM01            SM01_pKa1                 9.53           0.01
# 1             SM04            SM04_pKa1                 6.02           0.01
# 2             SM06            SM06_pKa1                 3.03           0.04
# 3             SM07            SM07_pKa1                 6.08           0.01
# 4             SM08            SM08_pKa1                 4.22           0.01
# 5             SM11            SM11_pKa1                 3.89           0.01
# 6             SM12            SM12_pKa1                 5.28           0.01
# 7             SM13            SM13_pKa1                 5.77           0.01
# 8             SM14            SM14_pKa1                 2.58           0.01
# 9             SM14            SM14_pKa2                 5.30           0.01
# 10            SM15            SM15_pKa1                 4.70           0.01
# 11            SM15            SM15_pKa2                 8.94           0.01
# 12            SM16            SM16_pKa1                 5.37           0.01
# 13            SM16            SM16_pKa2                10.65           0.01
# 14            SM17            SM17_pKa1                 3.16           0.01
# 15  Pyridoxine HCl  Pyridoxine HCl_pKa1                 4.83           0.01
# 16  Pyridoxine HCl  Pyridoxine HCl_pKa2                 8.86           0.01
#
#     pKa (UV-metric pKa with cosolvent)  pKa SEM cosolvent
# 0                                 9.71                NaN
# 1                                 5.97                NaN
# 2                                 3.44               0.02
# 3                                 5.96                NaN
# 4                                 4.47                NaN
# 5                                 3.74                NaN
# 6                                 5.16                NaN
# 7                                 5.68                NaN
# 8                                 2.56                NaN
# 9                                 5.29                NaN
# 10                                4.67                NaN
# 11                                9.01                NaN
# 12                                5.35                NaN
# 13                               11.01                NaN
# 14                                3.20                NaN
# 15                                4.85               0.01
# 16                                8.78               0.01

# %%
data = np.asarray(df_stat_conc[["pKa (UV-metric pKa)", "pKa (UV-metric pKa with cosolvent)"]])
print("slope:", format(slope(data), '.2f'))
print("mean difference:", format(me(data), '.2f'))
print("mean absolute difference:",format(mae(data), '.2f'))
print("R-squared:",format(r2(data), '.2f'))
print("RMSD:",format(rmse(data), '.2f'))
# Out:
# slope: 1.01
# mean difference: -0.04
# mean absolute difference: 0.12
# R-squared: 1.00
# RMSD: 0.17
